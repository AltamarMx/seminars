# %%
from iertools.read import read_epw
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import calplot
import numpy as np

# %%
plt.style.use('matplotlib.mplstyle')

# %%
f = 'data/Temixco_2018CST.epw'
df = read_epw(f,alias=True)

# %%
#| label: fig-temixco-to
#| fig-cap: Temperatura ambiente en Temixco, Morelos, $T_{prom}=22.8 ^oC$
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(df.To,'k-',alpha=0.3)
ax.plot(df.To.resample('D').mean())
ax.hlines(df.To.resample('YE').mean(),df.index[0],df.index[-1],color='green',alpha=0.4)
ax.set_ylim(4,40)
ax.set_ylabel('Temperatura [$^oC$]')
ax.xaxis.set_major_formatter(mdates.ConciseDateFormatter(mdates.AutoDateLocator()))

# %%
df.To.resample('Y').mean()
# Out:
# /var/folders/5r/jn_g7h3n0pv3v9fbjgr05h8w0000gn/T/ipykernel_2256/345586061.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df.To.resample('Y').mean()
# tiempo
# 2018-12-31    22.837597
# Freq: YE-DEC, Name: To, dtype: float64
